# %%
import pandas as pd
import numpy as np

# %%
dataframe = pd.read_csv("denver-1.nov.csv")
dataframe.head(35)
# Out:
#     raw_row_number        date      time                            location  \
# 0                1  2012-11-13  00:02:22                8500 W CRESTLINE AVE
# 1               16  2012-11-29  00:25:01                8500 W CRESTLINE AVE
# 2               72  2012-11-23  22:58:10                  4830 S HOLLAND WAY
# 3              121  2012-11-27  17:48:33                    4885 S QUEBEC ST
# 4              138  2012-11-14  23:46:58     W LAYTON AVE / S WADSWORTH BLVD
# 5              166  2012-11-27  00:49:39                   4490 S KIPLING ST
# 6              178  2012-11-07  00:45:42                   4490 S KIPLING ST
# 7              207  2012-11-08  01:13:30                   4490 S KIPLING ST
# 8              287  2012-11-06  22:38:59                8500 W CRESTLINE AVE
# 9              300  2012-11-13  23:49:22                8500 W CRESTLINE AVE
# 10             301  2012-11-08  04:41:15                8500 W CRESTLINE AVE
# ...

# %%
dataframe.groupby("district").agg({"arrest_made": sum})
# Out:
#           arrest_made
# district
# 1               200.0
# 2               254.0
# 3               113.0
# 4               149.0
# 5                60.0
# 6               186.0
# 7                 0.0
# None             23.0

# %%
dataframe['arrest_made']=dataframe['arrest_made'].map({False:0,True:1})
agg = dataframe.groupby(["district"]).agg({"arrest_made":np.mean})
(agg)
# Out:
#           arrest_made
# district
# 1            0.172712
# 2            0.189836
# 3            0.116736
# 4            0.128670
# 5            0.105079
# 6            0.185259
# 7            0.000000
# None         0.138554
